# %% [markdown]
# # Import Libraries
# - Seaborn automatically installs these libraries
# - numpy
# - scipy
# - pandas
# - matplotlib
#
#  # Line plot is a relationship between two continuous variables

# %% [markdown]
# ## Adding titles

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data set
phool = sns.load_dataset("iris")
phool

# draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.show()

# %% [markdown]
# ## Adding Limits

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data set
phool = sns.load_dataset("iris")
phool

# draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
# ## set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Load data set
phool = sns.load_dataset("iris")
phool

# draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
sns.set_style("dark")
set_style(style=none,rc=none)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2636/135939212.py in <module>
#      11 plt.title("phoolon ka plot")
#      12 sns.set_style("dark")
# ---> 13 set_style(style=none,rc=none)
#      14 plt.show()
#
# NameError: name 'set_style' is not defined

# %% [markdown]
# ## size of figure

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data set
phool = sns.load_dataset("iris")
phool

# change figure 
plt.figure(figsize=(4,2))

# draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")

plt.show()
